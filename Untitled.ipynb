# %%
from __future__ import print_function
import cv2 
import numpy as np
import matplotlib.pyplot as plt
import cvlib as cv
from cvlib.object_detection import draw_bbox

# %%
img = cv2.imread(r'D:\COMP 426-HW\pinterest\food\00ccaf8308af3c606dec2bedc09bb461.jpg')
print(img.shape)
# Out:
# (236, 236, 3)

# %%
bbox, label, conf = cv.detect_common_objects(img)
output_image = draw_bbox(img, bbox, label, conf)
plt.imshow(output_image)
plt.show()

# %%
import os, math, numpy

# %%
imls=os.listdir('food')

# %%
len(imls)
# Out:
# 245

# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
fig5 = plt.figure(constrained_layout=True, figsize=(20,20))

spec5 = fig5.add_gridspec(ncols=3, nrows=3)

i=0
labells=[]
for row in range(3):
    for col in range(3):
        ax = fig5.add_subplot(spec5[row, col])
        img = cv2.imread(r'D:\COMP 426-HW\pinterest\food\\'+ imls[i])
        bbox, label, conf = cv.detect_common_objects(img)
        labells.append(label)
        output_image= draw_bbox(img, bbox, label, conf)
        output_image = cv2.cvtColor(output_image, cv2.COLOR_BGR2RGB)
        ax.imshow( output_image)
        i+=1

# %%
labells
# Out:
# [['cup'],
#  ['bowl', 'broccoli', 'broccoli', 'broccoli'],
#  [],
#  [],
#  [],
#  ['sandwich'],
#  [],
#  [],
#  ['cup']]

# %%
dim=math.ceil(math.sqrt(len(imls)))
